# %% [markdown]
# # Aqui importo las librerias

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Lo que esta entre comillas es la direccion al archivo si lo subes a la pagina que te di solo cambia el nombre cualquier vaina me avisas

# %%
A=np.loadtxt("data.txt")

# %%
X=A[0]
Y=A[1]

# %% [markdown]
# # Comentado esta si lo quieres Dejar fijo solo imita para str2 y borra lo que no esta comentado

# %%
print('maria mi amiga querida introduce lo que quieras que diga en la horizontal')
str1=str(input())
#str1="Aqui lo que quieras"
print('maria mi amiga querida introduce lo que quieras que diga en la vertital')
str2=str(input())
# Out:
# maria mi amiga querida introduce lo que quieras que diga en la horizontal
#
# maria mi amiga querida introduce lo que quieras que diga en la vertital

# %% [markdown]
# # Si le quieres a;adir detalles esteticos a la grafica me avisas , creo que la partirias si envias el informe en un notebook como este

# %%
plt.rcParams['axes.facecolor'] = "#ccccb3"
plt.xlabel(str1)
plt.ylabel(str2)
plt.grid(color='black',fillstyle="full",alpha=0.4)
plt.plot(X,Y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
