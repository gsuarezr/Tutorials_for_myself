# %%
from sympy import *

# %%
k1,k2,x,z,alpha=symbols('k1 k2 x z alpha',real=True)

# %%
#u=cosh(k1*x)*exp(I * k1**2 * z ) +alpha*cosh(k2*x)*exp(I * k2**2 *z)
u=cosh(k1*x)*exp(I * k1**2 * z ) +I*alpha*sinh(k2*x)*exp(I * k2**2 *z)
l1=0
u
# Out:
# I*alpha*exp(I*k2**2*z)*sinh(k2*x) + exp(I*k1**2*z)*cosh(k1*x)

# %%
def VL(Vo,l1,u):
    V=Vo+I*diff(log(l1),z) -2 * diff(log(u),x,2)
    V=simplify(V)
    return V

# %%
V=VL(0,0,u)
reV=re(V)
imV=im(V)

# %%
from sympy.plotting import plot3d
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
plot3d(reV.subs({k1:0.4, k2: 0.1,alpha:0.5}),(x,-15,15),(z,-60,60),xlabel=r'$\theta_{1}$'
               ,ylabel=r'$\theta_{2}$',title=r'$Probablity$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot3d(imV.subs({k1:0.4, k2: 0.1,alpha:0.5}),(x,-15,15),(z,-60,60),xlabel=r'$\theta_{1}$'
               ,ylabel=r'$\theta_{2}$',title=r'$Probablity$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#v= sinh(k1*x)* exp(I * k1**2 * z) + alpha*sinh(k2*x)*exp(I* k2 **2 *z)
v=sinh(k1*x)* exp(I * k1**2 * z) + I*alpha*cosh(k2*x)*exp(I* k2 **2 *z)
v
# Out:
# I*alpha*exp(I*k2**2*z)*cosh(k2*x) + exp(I*k1**2*z)*sinh(k1*x)

# %%
def L(u,v):
    Vn=diff(v,x)- diff(u,x) * (v/u)
    return Vn

Vn=L(u,v)
simplify(Vn)
# Out:
# (alpha**2*k2*exp(2*I*k2**2*z) - I*alpha*(k1 + k2)*exp(I*z*(k1**2 + k2**2))*sinh(x*(k1 - k2)) + k1*exp(2*I*k1**2*z))/(I*alpha*exp(I*k2**2*z)*sinh(k2*x) + exp(I*k1**2*z)*cosh(k1*x))

# %%
# Out:
# alpha*k2*exp(I*k2**2*z)*sinh(k2*x) + k1*exp(I*k1**2*z)*sinh(k1*x)

# %%
Vn= Vn*conjugate(Vn)

# %%
plot3d(Vn.subs({k1:0.4, k2: 0.1,alpha:0.5}),(x,-15,15),(z,-60,60),xlabel=r'$\theta_{1}$'
               ,ylabel=r'$\theta_{2}$',title=r'$Probablity$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Potencia=autowrap(x+z)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sympy\utilities\autowrap.py in _process_files(self, routine)
#     168         try:
# --> 169             retoutput = check_output(command, stderr=STDOUT)
#     170         except CalledProcessError as e:
#
# ~\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# ...

# %% [markdown]
# ![paquete.png](attachment:paquete.png)

# %%
sigma,z0,x0,v0=symbols('sigma z0 x0 v0',real=True)

# %%
paquete=(1/sqrt(I*(z-z0)+sigma))*exp(- (x-x0+v0*(z-z0))**2 / (4*(I*(z-z0)+sigma))-(I/4)*v0*(2*x+v0*z))
paquete
# Out:
# exp(-I*v0*(v0*z + 2*x)/4 - (v0*(z - z0) + x - x0)**2/(4*sigma + 4*I*(z - z0)))/sqrt(sigma + I*(z - z0))

# %%
Phi=L(u,paquete)

# %%
paquetito=(Phi*conjugate(Phi))

# %%
plot3d(paquetito.subs({k1:0.4, k2: 0.1,alpha:0.5,x0:-7,z0:-50,v0:0.2,sigma:40}),(x,-50,50),(z,-50,60),xlabel=r'$\theta_{1}$'
               ,ylabel=r'$\theta_{2}$',title=r'$Probablity$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
u=

# %%
V=VL(0,0,u)
V
# Out:
# 0
